# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffrinrohit28it-spec/githworkshop/blob/main/day2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import spacy
 nlp = spacy.load('en_core_web_sm')

# %%
from spacy.matcher import Matcher
matcher =Matcher(nlp.vocab)

# %%
from ast import pattern
pattern1=[{'LOWER': 'solarpower'}]
pattern2=[{'LOWER': 'solar'},{'LOWER': 'power'}]
pattern3=[{'LOWER': 'solar'},{'IS_PUNCT':True},{'LOWER': 'power'}]

# %%
matcher.add('SolarPower', [pattern1, pattern2, pattern3])

# %%
doc = nlp(u'The Solar Power industry continues to grow as demand \for solarpower increases. Solar-power cars are gaining popularity.')

# %%
found_matches = matcher(doc)
print(found_matches)
# Out:
# [(8656102463236116519, 1, 3), (8656102463236116519, 11, 12), (8656102463236116519, 14, 17)]

# %%
for match_id, start, end in found_matches:
  string_id = nlp.vocab.strings[match_id]
  span = doc[start:end]
  print(match_id, string_id, start, end, span.text)
# Out:
# 8656102463236116519 SolarPower 1 3 Solar Power
# 8656102463236116519 SolarPower 11 12 solarpower
# 8656102463236116519 SolarPower 14 17 Solar-power

# %%
doc2 = nlp(u'Solar-power energy runs solar-power cars.')

# %%
found_matches = matcher(doc2)
print(found_matches)
# Out:
# [(8656102463236116519, 0, 3), (8656102463236116519, 5, 8)]

# %%
matcher.remove('SolarPower')

# %%
pattern1=[{'LOWER': 'solarpower'}]
pattern2=[{'LOWER': 'solar'},{'IS_PUNCT':True,'op':'*'},{'LOWER': 'power'}]
pattern3=[{'LOWER': 'solarpowered'}]
pattern2=[{'LOWER': 'solar'},{'IS_PUNCT':True,'op':'*'},{'LOWER': 'powered'}]

# %%
found_matches = matcher(doc2)
print(found_matches)
# Out:
# []

# %%
from spacy.matcher import PhraseMatcher
matcher = PhraseMatcher(nlp.vocab)

# %%
pwd
# Out:
# '/content'

# %%
phrase_list = ['voodoo economics','supply-side economics','trickle-down economics','free-market economics']

# %%
phrase_patterns = [nlp(text) for text in phrase_list]

# %%
matches = matcher(doc)

# %%
doc3 = nlp("Your text here")

# %%
sents = [sent for sent in doc3.sents]

print(sents[0].start,sents[0].end)
# Out:
# 0 3

# %%
for sent in sents:
  if matches:
    if matches[4][1] < sent.end:
        print(sent)
        break
  else:
    print('no mathes ')
    break
# Out:
# no mathes
