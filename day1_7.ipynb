# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffrinrohit28it-spec/githworkshop/blob/main/day1_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem.porter import *
p_stemmer = PorterStemmer()
words = 'consolingly'

# %%
print('Porter Stemmer:')
for word in words:
    print(word+' --> '+p_stemmer.stem(word))
# Out:
# Porter Stemmer:
# c --> c
# o --> o
# n --> n
# s --> s
# o --> o
# l --> l
# i --> i
# n --> n
# g --> g
# l --> l
# y --> y

# %%
from nltk.stem.snowball import SnowballStemmer
s_stemmer = SnowballStemmer(language='english')

# %%
print('Porter2 Stemmer')
for word in words:
  print(word+' --> '+p_stemmer.stem(word))
# Out:
# Porter2 Stemmer
# c --> c
# o --> o
# n --> n
# s --> s
# o --> o
# l --> l
# i --> i
# n --> n
# g --> g
# l --> l
# y --> y

# %%
phrase = 'I am meeting him tomorrow at the meeting'
for word in phrase.split():
  print(word+' --> '+p_stemmer.stem(word))
# Out:
# I --> i
# am --> am
# meeting --> meet
# him --> him
# tomorrow --> tomorrow
# at --> at
# the --> the
# meeting --> meet

# %%
phrase = 'venu playing games'
for word in phrase.split():
  print(word+' --> '+p_stemmer.stem(word))
# Out:
# venu --> venu
# playing --> play
# games --> game
